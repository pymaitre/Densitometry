# %%
#requirements: numpy, pandas, openpyxl, SimpleITK, pydicom, platipy

from pathlib import Path
import merge_df as merge_df

# %%
def main():  
    directory_out = Path.home() / "Desktop" / "Cardio" / ".venv_Fin" / "Histo_Heart" / "Analyses"
    Path(directory_out).mkdir(parents=True, exist_ok=True)

    if "y" in str(input("Do you want to merge clinical and densitometric database? (y/n)")).lower():
        print("You chose to merge databases.")

        show_merge = str(input("\nDo you want to see all the dataframes until the final one? (y/n)"))
        save_merge = str(input("Do you want to save them? (y/n)"))
        merge_df.merge_db(directory_out, show_merge, save_merge)
    
    else:
        print("You chose not to merge databases.")
        print("")

# %%
if __name__ == "__main__":
    main()
# Out:
# Do you want to merge clinical and densitometric database? (y/n) y
# You chose to merge databases.
# Do you want to see all the dataframes until the final one? (y/n) y
# Do you want to save the final database? (y/n) n
# The showing option is set on:  True
# The saving option is set on:  False
# Insert the name of the database:  patient
# The database is in: C:\Users\belardo.alfonso\Desktop\Cardio\.venv_Fin\Histo_Heart\Analyses\py_patient_file.xlsx
#    PatientID         PatientName  PatientAge  VoxelSpacingX  VoxelSpacingY  \
# 0     284444    STIZIOLI, MARISA          71       0.976562       0.976562
# 1     298615      MARI, CATERINA          66       0.976562       0.976562
# 2     299522  PANIZZOLO, NEREIDE          81       0.976562       0.976562
#
#    VoxelSpacingZ                                               Path
# 0              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
# 1              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
# 2              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
# Is this the file you were looking for?  y
# Do you have a database that has to be merged? y
# Insert the name of the database:  clinico
# No Excel file found with the name 'clinico'. Try again.
# Insert the name of the database:  clinic
# No Excel file found with the name 'clinic'. Try again.
# Insert the name of the database:  over
# The database is in: C:\Users\belardo.alfonso\Desktop\Cardio\.venv_Fin\Histo_Heart\Analyses\Over_rate_regions\Region_over_-150_150_0.5\Stats_over_-150_150_0.5.xlsx
#    PatientID  Min_Region_over_-150_150_0.5  Max_Region_over_-150_150_0.5  \
# 0     298615                          -645                           420
# 1     299522                          -577                          -151
#
#    Tot_counts_Region_over_-150_150_0.5  Mean_Region_over_-150_150_0.5  \
# 0                                  662                    -101.521148
# 1                                  889                    -220.195726
#
#    Mode_Region_over_-150_150_0.5  Count_Max_Region_over_-150_150_0.5  \
# 0                           -154                                  22
# 1                           -159                                  29
#
#    Median_Region_over_-150_150_0.5  Std Dev_Region_over_-150_150_0.5  \
# 0                             -162                        189.738328
# 1                             -189                         84.395061
#
#    Skewness_Region_over_-150_150_0.5  Kurtosis_Region_over_-150_150_0.5  \
# 0                           0.797476                          -0.107985
# 1                          -1.847236                           3.123650
#
#    10th Percentile_Region_over_-150_150_0.5  \
# 0                                      -251
# 1                                      -338
#
#    25th Percentile_Region_over_-150_150_0.5  \
# 0                                   -193.75
# 1                                   -245.00
#
#    75th Percentile_Region_over_-150_150_0.5  \
# 0                                      -151
# 1                                      -162
#
#    90th Percentile_Region_over_-150_150_0.5
# 0                                       204
# 1                                      -155
# Is this the file you were looking for?  no
# Try again.
# Insert the name of the database:  specific
# The database is in: C:\Users\belardo.alfonso\Desktop\Cardio\.venv_Fin\Histo_Heart\Analyses\Specific_Regions\Region_-150_150_3\Stats_specific_-150_150_3.xlsx
#    PatientID  Min_Region_-150_150_3  Max_Region_-150_150_3  \
# 0     284444                   -149                    126
# 1     298615                   -149                    146
# 2     299522                   -149                     98
#
#    Tot_counts_Region_-150_150_3  Mean_Region_-150_150_3  \
# 0                        115066               25.815228
# 1                        125736               22.355952
# 2                        131974               11.709503
#
#    Mode_Region_-150_150_3  Count_Max_Region_-150_150_3  \
# 0                      46                         2569
# 1                      40                         2869
# 2                      36                         2701
#
#    Median_Region_-150_150_3  Std Dev_Region_-150_150_3  \
# 0                        38                  37.131723
# 1                        33                  38.042088
# 2                        28                  45.634604
#
#    Skewness_Region_-150_150_3  Kurtosis_Region_-150_150_3  \
# 0                   -1.602907                    2.479805
# 1                   -1.595569                    2.887948
# 2                   -1.428636                    1.245722
#
#    10th Percentile_Region_-150_150_3  25th Percentile_Region_-150_150_3  \
# 0                              -29.0                                 15
# 1                              -32.5                                 13
# 2                              -65.0                                 -2
#
#    75th Percentile_Region_-150_150_3  90th Percentile_Region_-150_150_3
# 0                                 49                                 58
# 1                                 45                                 55
# 2                                 41                                 51
# Is this the file you were looking for?  y
# Do you need to merge or modify first db columns for merging? n
# Do you need to merge or modify the second db columns for merging? n
# The columns names of the left db are:
# Index(['PatientID', 'PatientName', 'PatientAge', 'VoxelSpacingX',
#        'VoxelSpacingY', 'VoxelSpacingZ', 'Path'],
#       dtype='object')
#
# The columns names of the right db are:
# Index(['PatientID', 'Min_Region_-150_150_3', 'Max_Region_-150_150_3',
#        'Tot_counts_Region_-150_150_3', 'Mean_Region_-150_150_3',
#        'Mode_Region_-150_150_3', 'Count_Max_Region_-150_150_3',
#        'Median_Region_-150_150_3', 'Std Dev_Region_-150_150_3',
#        'Skewness_Region_-150_150_3', 'Kurtosis_Region_-150_150_3',
#        '10th Percentile_Region_-150_150_3',
#        '25th Percentile_Region_-150_150_3',
#        '75th Percentile_Region_-150_150_3',
#        '90th Percentile_Region_-150_150_3'],
#       dtype='object')
# Which column you want to merge left db on? PatientID
# I matched the name:  PatientID
# Which column you want to merge right db on? PatientID
# I matched the name:  PatientID
#    PatientID_x         PatientName  PatientAge  VoxelSpacingX  VoxelSpacingY  \
# 0       284444    STIZIOLI, MARISA          71       0.976562       0.976562
# 1       298615      MARI, CATERINA          66       0.976562       0.976562
# 2       299522  PANIZZOLO, NEREIDE          81       0.976562       0.976562
#
#    VoxelSpacingZ                                               Path  LinkCol  \
# 0              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...   284444
# 1              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...   298615
# 2              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...   299522
#
#    PatientID_y  Min_Region_-150_150_3  ...  Mode_Region_-150_150_3  \
# 0       284444                   -149  ...                      46
# 1       298615                   -149  ...                      40
# 2       299522                   -149  ...                      36
#
#    Count_Max_Region_-150_150_3  Median_Region_-150_150_3  \
# 0                         2569                        38
# 1                         2869                        33
# 2                         2701                        28
#
#    Std Dev_Region_-150_150_3  Skewness_Region_-150_150_3  \
# 0                  37.131723                   -1.602907
# 1                  38.042088                   -1.595569
# 2                  45.634604                   -1.428636
#
#    Kurtosis_Region_-150_150_3  10th Percentile_Region_-150_150_3  \
# 0                    2.479805                              -29.0
# 1                    2.887948                              -32.5
# 2                    1.245722                              -65.0
#
#    25th Percentile_Region_-150_150_3  75th Percentile_Region_-150_150_3  \
# 0                                 15                                 49
# 1                                 13                                 45
# 2                                 -2                                 41
#
#    90th Percentile_Region_-150_150_3
# 0                                 58
# 1                                 55
# 2                                 51
#
# [3 rows x 23 columns]
# The columns names are:
# Index(['PatientID_x', 'PatientName', 'PatientAge', 'VoxelSpacingX',
#        'VoxelSpacingY', 'VoxelSpacingZ', 'Path', 'LinkCol', 'PatientID_y',
#        'Min_Region_-150_150_3', 'Max_Region_-150_150_3',
#        'Tot_counts_Region_-150_150_3', 'Mean_Region_-150_150_3',
#        'Mode_Region_-150_150_3', 'Count_Max_Region_-150_150_3',
#        'Median_Region_-150_150_3', 'Std Dev_Region_-150_150_3',
#        'Skewness_Region_-150_150_3', 'Kurtosis_Region_-150_150_3',
#        '10th Percentile_Region_-150_150_3',
#        '25th Percentile_Region_-150_150_3',
#        '75th Percentile_Region_-150_150_3',
#        '90th Percentile_Region_-150_150_3'],
#       dtype='object')
# Do you want to drop a column?  y
# The columns names are:
# Index(['PatientID_x', 'PatientName', 'PatientAge', 'VoxelSpacingX',
#        'VoxelSpacingY', 'VoxelSpacingZ', 'Path', 'LinkCol', 'PatientID_y',
#        'Min_Region_-150_150_3', 'Max_Region_-150_150_3',
#        'Tot_counts_Region_-150_150_3', 'Mean_Region_-150_150_3',
#        'Mode_Region_-150_150_3', 'Count_Max_Region_-150_150_3',
#        'Median_Region_-150_150_3', 'Std Dev_Region_-150_150_3',
#        'Skewness_Region_-150_150_3', 'Kurtosis_Region_-150_150_3',
#        '10th Percentile_Region_-150_150_3',
#        '25th Percentile_Region_-150_150_3',
#        '75th Percentile_Region_-150_150_3',
#        '90th Percentile_Region_-150_150_3'],
#       dtype='object')
# Insert the name of the column you want to drop:  _y
# I matched the name:  PatientID_y
# Do you want to drop a column?  y
# The columns names are:
# Index(['PatientID_x', 'PatientName', 'PatientAge', 'VoxelSpacingX',
#        'VoxelSpacingY', 'VoxelSpacingZ', 'Path', 'LinkCol',
#        'Min_Region_-150_150_3', 'Max_Region_-150_150_3',
#        'Tot_counts_Region_-150_150_3', 'Mean_Region_-150_150_3',
#        'Mode_Region_-150_150_3', 'Count_Max_Region_-150_150_3',
#        'Median_Region_-150_150_3', 'Std Dev_Region_-150_150_3',
#        'Skewness_Region_-150_150_3', 'Kurtosis_Region_-150_150_3',
#        '10th Percentile_Region_-150_150_3',
#        '25th Percentile_Region_-150_150_3',
#        '75th Percentile_Region_-150_150_3',
#        '90th Percentile_Region_-150_150_3'],
#       dtype='object')
# Insert the name of the column you want to drop:  ink
# I matched the name:  LinkCol
# Do you want to drop a column?  n
#    PatientID_x         PatientName  PatientAge  VoxelSpacingX  VoxelSpacingY  \
# 0       284444    STIZIOLI, MARISA          71       0.976562       0.976562
# 1       298615      MARI, CATERINA          66       0.976562       0.976562
# 2       299522  PANIZZOLO, NEREIDE          81       0.976562       0.976562
#
#    VoxelSpacingZ                                               Path  \
# 0              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
# 1              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
# 2              5  C:\Users\belardo.alfonso\Desktop\Cardio\.venv_...
#
#    Min_Region_-150_150_3  Max_Region_-150_150_3  Tot_counts_Region_-150_150_3  \
# 0                   -149                    126                        115066
# 1                   -149                    146                        125736
# 2                   -149                     98                        131974
#
#    ...  Mode_Region_-150_150_3  Count_Max_Region_-150_150_3  \
# 0  ...                      46                         2569
# 1  ...                      40                         2869
# 2  ...                      36                         2701
#
#    Median_Region_-150_150_3  Std Dev_Region_-150_150_3  \
# 0                        38                  37.131723
# 1                        33                  38.042088
# 2                        28                  45.634604
#
#    Skewness_Region_-150_150_3  Kurtosis_Region_-150_150_3  \
# 0                   -1.602907                    2.479805
# 1                   -1.595569                    2.887948
# 2                   -1.428636                    1.245722
#
#    10th Percentile_Region_-150_150_3  25th Percentile_Region_-150_150_3  \
# 0                              -29.0                                 15
# 1                              -32.5                                 13
# 2                              -65.0                                 -2
#
#    75th Percentile_Region_-150_150_3  90th Percentile_Region_-150_150_3
# 0                                 49                                 58
# 1                                 45                                 55
# 2                                 41                                 51
#
# [3 rows x 21 columns]
# Do you have a database that has to be merged? n
# Do you want to drop patients from the merged db? n
# You chose to not drop patients.
#
# You have finished.
